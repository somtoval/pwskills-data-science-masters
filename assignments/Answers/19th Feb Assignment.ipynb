# %% [markdown]
# ### Q1. What is Flask Framework? What are the advantages of Flask Framework?

# %% [markdown]
# Ans - Flask is a popular Python web framework that is used for building web applications. It is a lightweight and modular framework that provides developers with the flexibility to customize and create web applications as per their requirements.
#
# Some of the advantages of Flask framework are:
#
# Lightweight and Flexible: Flask is a lightweight framework that provides developers with the flexibility to customize and create web applications as per their requirements.
#
# Easy to learn: Flask has a simple and easy-to-learn API. It is based on the principle of simplicity, making it easier for beginners to understand and start building web applications.
#
# Built-in Development Server: Flask comes with a built-in development server, which makes it easy to test and debug the application during development.
#
# Modular Design: Flask follows a modular design, allowing developers to use only the required components and extensions to build a web application.

# %% [markdown]
# ### Q2. Create a simple Flask application to display ‘Hello World!!’. Attach the screenshot of the output in Jupyter Notebook.

# %% [markdown]
# ![Screenshot%20%2838%29.png](attachment:Screenshot%20%2838%29.png)

# %% [markdown]
# ### Q3. What is App routing in Flask? Why do we use app routes?

# %% [markdown]
# In Flask, app routing is a way to map URLs to Python functions that handle requests. When a user visits a specific URL in a web application, Flask uses app routing to match the URL to a specific function in the codebase, which generates the response that is sent back to the user's web browser.

# %%
@app.route('/')
def index():
    return 'This is the homepage'

# %% [markdown]
# In this example, the @app.route('/') decorator tells Flask to map the root URL of the application (i.e., http://example.com/) to the index() function. When a user visits the root URL, Flask calls the index() function and returns the response, which in this case is a simple string.
#
# We use app routes in Flask to define the URLs of our web application and to map those URLs to specific functions that generate the responses that are sent back to the user's web browser. App routing allows us to create a structured and logical flow of information within our application and make it easy for users to navigate between different pages and sections of the application.

# %% [markdown]
# ### Q4. Create a “/welcome” route to display the welcome message “Welcome to ABC Corporation” and a “/” route to show the following details:
#
# #### Company Name: ABC Corporation
# #### Location: India
# #### Contact Detail: 999-999-9999

# %%
from flask import Flask

app = Flask(__name__)

@app.route('/welcome')
def welcome():
    return 'Welcome to ABC Corporation'

@app.route('/')
def index():
    return 'Company Name: ABC Corporation<br>Location: India<br>Contact Detail: 999-999-9999'

if __name__ == '__main__':
    app.run()

# %% [markdown]
# ![Screenshot%20%2839%29.png](attachment:Screenshot%20%2839%29.png)

# %% [markdown]
# ![Screenshot%20%2840%29.png](attachment:Screenshot%20%2840%29.png)

# %% [markdown]
# ### Q5. What function is used in Flask for URL Building? Write a Python code to demonstrate the working of the url_for() function.

# %% [markdown]
# In Flask, the url_for() function is used for URL building. This function generates a URL for a specific function in the application based on its name and any arguments that need to be passed to it.

# %%
from flask import Flask, url_for

app = Flask(__name__)

@app.route('/')
def index():
    return f'The URL for the welcome() function is {url_for("welcome")}'

@app.route('/welcome')
def welcome():
    return 'Welcome to ABCD Corporation'

if __name__ == '__main__':
    app.run()

# %% [markdown]
# In this example, we import the url_for() function from the Flask module and use it to generate a URL for the welcome() function. In the index() function, we use the url_for() function to generate the URL for the welcome() function and return it as a string.
